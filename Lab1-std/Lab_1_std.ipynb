# %%
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage import color
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np
from skimage.util import random_noise
import numpy as np
import os 

from skimage.exposure import histogram
from matplotlib.pyplot import bar

# %%
def show_images(images,titles=None):
    #This function is used to show image(s) with titles by sending an array of images and an array of associated titles.
    # images[0] will be drawn with the title titles[0] if exists
    # You aren't required to understand this function, use it as-is.
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure()
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n)
        if image.ndim == 2: 
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
        n += 1
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_ims)
    plt.show()

# %%
# Ex: imread and imshow 
pyramids = io.imread('pyramids.jpeg')
io.imshow(pyramids)
io.show()
# Out:
# /tmp/ipykernel_37344/603621990.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(pyramids)
# /tmp/ipykernel_37344/603621990.py:4: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
# Use this function to show a histogram
# The image should be gray-scale and should range from 0 to 1
def showHist(img,histogramImg):
    plt.figure()
    bar(histogramImg[1]*255, histogramImg[0], width=0.8, align='center')

# %%
'''
@TODO:
Requirement #1 
-Read and print image 'coffee'  
-Show and print half of the  image
-----hint :use the attribute shape of numpy to get the image object dimentions
'''

coffee = io.imread('coffee.jpeg')
print(coffee)
io.imshow(coffee)
io.show()

half_coffee_left = coffee[:, :coffee.shape[1]//2]  # all rows, first half of columns
half_coffee_right = coffee[:, coffee.shape[1]//2:] # all rows, second half of columns
half_coffee_up = coffee[:coffee.shape[0]//2, :]    # first half of rows, all columns
half_coffee_down = coffee[coffee.shape[0]//2 :, :] # second half of rows, all columns

show_images([half_coffee_left, half_coffee_right, half_coffee_up, half_coffee_down],
            ['Left Half', 'Right Half', 'Upper Half', 'Lower Half'])

print(half_coffee_left, half_coffee_right, half_coffee_up, half_coffee_down)
# Out:
# /tmp/ipykernel_37344/2112624800.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(coffee)
# /tmp/ipykernel_37344/2112624800.py:12: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# [[[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  [[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  [[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  ...
#
#  [[229 231 244]
#   [229 231 244]
#   [229 231 244]
#   ...
#   [228 230 243]
#   [228 230 243]
#   [228 230 243]]
#
#  [[229 231 244]
#   [229 231 244]
#   [229 231 244]
#   ...
#   [228 230 243]
# ...

# %%
'''
@TODO:
Requirement #2 
RGB to gray and HSV:
1- Write a function 'gray_image' that takes an image as input , then
    -get the gray scale of the image, then
    -display original image and the gray scale one side by side (subplot).
    -hint: use rgb2gray to get the graylevel of the image
- test your function with the image 'pyramids'
    
2- Write a function 'HSV_image' that takes an image as input , then
   -show the RGB image and the (3 channels of HSV image each channel in separated form ) one side by side (subplot).
   -hint: -use rgb2hsv (to get the hsv representation of the image).
          -To separately get the Hue, Saturation and Value channels, use hsvImg[:,:,X], 
           where hsvImg is the hsv representation of the image. 
           Hue is the first channel, Saturation is the second and value is the last channel.
- test your function for the images in HSV Folder. And comment on the results. 
'''

def gray_image(image):
    gray_img = rgb2gray(image)
    show_images([image, gray_img], ['Original Image', 'Gray Scale Image'])

gray_image(pyramids)

def HSV_image(image):
    hsv_img = rgb2hsv(image)
    hue_channel = hsv_img[:, :, 0]
    sat_channel = hsv_img[:, :, 1]
    val_channel = hsv_img[:, :, 2]
    show_images([image, hue_channel, sat_channel, val_channel],
                ['Original Image', 'Hue Channel', 'Saturation Channel', 'Value Channel'])

imgs = io.imread_collection('./hsv/*')
for img in imgs:
    HSV_image(img)

# %%
'''
Requirement 2 (Noise):
http://scikit-image.org/docs/dev/api/skimage.util.html#skimage.util.random_noise

1.For an image of your choice (the effect of noise must be obvious): 
    Read the image.
    Convert it to greyscale.
    Apply salt & pepper noise with 
    amount=0.05, 0.5 and 0.9
   
2. From the other images. Recommend one image that won’t be greatly affected by the noise and state why.    
    '''

cats = io.imread('cats.jpeg')
cats_gray = rgb2gray(cats)
noisy_05 = random_noise(cats_gray, mode='s&p', amount=0.05)
noisy_5 = random_noise(cats_gray, mode='s&p', amount=0.5)
noisy_9 = random_noise(cats_gray, mode='s&p', amount=0.9)

show_images([cats, cats_gray, noisy_05, noisy_5, noisy_9], ['Original Image', 'Gray Scale Image', 'Noisy 0.05', 'Noisy 0.5', 'Noisy 0.9'])


# the pyramids image won't be greatly affected by the noise because it has black and white dots (the sand) making the noise look like part of the image

# %%
'''
Requirement 3 (Histogram):

1- For the given images ( in histogram folder): 
    Read the image.
    Apply histogram and show it.
Hint
    A) Use histogram (image) to get histogram. Try different values for nbins (256,64,8), What does it mean?
    B) and function(showHist) to draw it.
** 2- Draw a grey-scale image that has uniform histogram 
same number of pixels for all intensity levels) using code only. Let the size of the image be 256x256.
use np.ones to draw image with ones.
'''

hist_imgs = io.imread_collection('./histogram/*')
for img in hist_imgs:
    img_rgb = img[:, :, :3]
    img_gray = rgb2gray(img_rgb)
    hist256 = histogram(img_gray, nbins=256)
    hist64 = histogram(img_gray, nbins=64)
    hist8 = histogram(img_gray, nbins=8)
    showHist(img_gray, hist256)
    showHist(img_gray, hist64)
    showHist(img_gray, hist8)
# nbins is the number of bins to use for the histogram. A higher number of bins gives a more detailed histogram, while a lower number of bins gives a more general overview of the intensity distribution.
# it's the number of intensity levels (intervals) the histogram is divided into.


# 256*256 image with all 1s
uniform_img = np.ones((256, 256)) 

# 256 pixels for 256 levels = total 256² pixels
# so each row out of the 256 has a different intensity level
for i in range(256):
    uniform_img[i, :] = i / 255.0 

showHist(uniform_img, histogram(uniform_img, nbins=256))
showHist(uniform_img, histogram(uniform_img, nbins=64))
showHist(uniform_img, histogram(uniform_img, nbins=8))

# %%
io.imshow(uniform_img)
io.show()
# Out:
# /tmp/ipykernel_37344/3675735444.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(uniform_img)
# /tmp/ipykernel_37344/3675735444.py:2: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
